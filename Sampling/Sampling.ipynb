# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math
from scipy.stats import beta, dirichlet

# %%
mu = 0.001
variance = 0.001
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
a = 2
b = 6
dist = beta(a, b)
x = np.linspace(0, 1, 1002)[1:-1]
plt.plot(x, dist.pdf(x), ls='-', c='black',label=r'$\alpha=%.1f,\ \beta=%.1f$' % (a,b))

# %%
dist.rvs()
# Out:
# 1.0

# %%
# samples = np.random.beta(a,b, size=200)
samples
# Out:
# array([0.47180258, 0.5737535 , 0.18849749, 0.17952022, 0.18477334,
#        0.41359941, 0.13129856, 0.20305127, 0.29137393, 0.44266157,
#        0.20518985, 0.65473237, 0.0627887 , 0.47211997, 0.12304896,
#        0.1463963 , 0.17682366, 0.15826819, 0.15540521, 0.2827781 ,
#        0.58265056, 0.27993792, 0.19297655, 0.2589648 , 0.60270074,
#        0.54122937, 0.11678926, 0.37801188, 0.41247338, 0.15354038,
#        0.31248357, 0.21985262, 0.05598022, 0.18856761, 0.47599658,
#        0.13321033, 0.26238205, 0.14864836, 0.13008069, 0.73744617,
#        0.16268254, 0.17137665, 0.70658652, 0.23148938, 0.41354863,
#        0.44982478, 0.34652795, 0.31583492, 0.45927503, 0.78839835,
#        0.41749412, 0.24887061, 0.12800992, 0.225097  , 0.39024739,
#        0.58788084, 0.09256768, 0.24187319, 0.30492841, 0.47724666,
#        0.20619764, 0.15234941, 0.30012205, 0.27004244, 0.38049625,
#        0.26122745, 0.25521221, 0.30928936, 0.05325795, 0.2162665 ,
# ...

# %%
alpha = 0.5
size = 100
# samples = np.random.dirichlet(np.repeat(alpha, size))
samples = np.random.gamma(0.001, 0.001, size)
plt.scatter(range(size), samples)
# samples = []

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  
shape, scale = 3, 0.0001  # mean=4, std=2*sqrt(2)
s = np.random.gamma(shape, scale, 100)
count, bins, ignored = plt.hist(s, 20, density=True)
y = bins**(shape-1)*(np.exp(-bins/scale) /  
                     (sps.gamma(shape)*scale**shape))
plt.plot(bins, y, linewidth=2, color='r')
plt.yticks([])
plt.title(' Learning Rate Distribution ')
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  
shape, scale = 3, 0.0001  # mean=4, std=2*sqrt(2)
s = np.random.gamma(shape, scale, 100)
count, bins, ignored = plt.hist(s, 20, density=True)
y = bins**(shape-1)*(np.exp(-bins/scale) /  
                     (sps.gamma(shape)*scale**shape))
plt.plot(bins, y, linewidth=2, color='r')
plt.yticks([])
plt.title(' Weight Decay')
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  
mu, sigma = 0.5, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
# plt.yticks([])
plt.title('Non-IID partitioning alpha variance parameter')
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  
mu, sigma = 0.5, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')


# plt.yticks([])
plt.title('Non-IID partitioning alpha variance parameter')
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  

mu, sigma = 15, 4 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='b')

# plt.yticks([])
plt.title('Number of Round of Communications')
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  
mu, sigma = 0.5, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
# plt.yticks([])
plt.title('Non-IID partitioning alpha variance parameter')
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.special as sps  
shape, scale = 2., 2.  # mean=4, std=2*sqrt(2)
s = np.random.gamma(shape, scale, 1000)
count, bins, ignored = plt.hist(s, 50, density=True)
y = bins**(shape-1)*(np.exp(-bins/scale) /  
                     (sps.gamma(shape)*scale**shape))
plt.plot(bins, y, linewidth=2, color='r')  
plt.show()

# %%
s
# Out:
# array([3.60751592e-04, 9.18384860e-04, 3.34334147e-04, 4.22207946e-04,
#        5.64454526e-04, 1.99522067e-04, 4.23517726e-04, 4.04589143e-04,
#        4.30996015e-05, 7.46263794e-04, 2.08813906e-04, 9.65898338e-05,
#        3.47623706e-04, 2.42157652e-04, 1.93788176e-04, 3.71593404e-04,
#        4.16107932e-04, 2.99110389e-04, 1.50654270e-04, 1.06022344e-04,
#        1.17738808e-04, 2.45529886e-04, 1.92214968e-04, 4.00144725e-04,
#        1.98174148e-04, 1.91693547e-04, 3.65905369e-04, 9.08780671e-05,
#        3.04179993e-04, 1.73165775e-04, 3.57624802e-04, 8.85823047e-05,
#        7.02648625e-04, 2.40058503e-04, 7.07907264e-04, 2.10644607e-04,
#        8.90145781e-04, 5.50808438e-04, 4.14796139e-04, 1.86259648e-04,
#        2.77518413e-04, 8.42868903e-05, 7.67020289e-05, 1.73789651e-04,
#        2.91171641e-04, 4.66931760e-04, 1.30737034e-04, 1.59339056e-04,
#        2.83187194e-04, 3.39870243e-04, 3.47516056e-04, 5.77115585e-04,
# ...

# %%
plt.hist(samples, color = 'blue', edgecolor = 'black')
# Out:
# (array([74., 15.,  2.,  1.,  2.,  0.,  2.,  2.,  1.,  1.]),
#  array([3.05472440e-08, 1.00650732e-02, 2.01301158e-02, 3.01951584e-02,
#         4.02602010e-02, 5.03252436e-02, 6.03902862e-02, 7.04553288e-02,
#         8.05203714e-02, 9.05854140e-02, 1.00650457e-01]),
#  <BarContainer object of 10 artists>)

# %%
s = np.random.uniform(0.000001,1,100)
count, bins, ignored = plt.hist(s, 15, density=True)
plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
plt.show()

# %%
np.random.uniform(0,1,1000)
# Out:
# array([0.5897571 , 0.84395046, 0.98695301, 0.08226926, 0.1367349 ,
#        0.65488808, 0.48710116, 0.35340208, 0.98133485, 0.57149288,
#        0.14976951, 0.95663247, 0.38214172, 0.55692413, 0.69786784,
#        0.6153197 , 0.25286941, 0.78447089, 0.74061785, 0.8363307 ,
#        0.85706828, 0.50656388, 0.77262674, 0.97018469, 0.7240347 ,
#        0.82205017, 0.04554451, 0.68996452, 0.93844147, 0.18869   ,
#        0.58430561, 0.85734617, 0.75644519, 0.55925117, 0.83782117,
#        0.12993356, 0.09867981, 0.65742778, 0.2450769 , 0.88972386,
#        0.01179756, 0.9177674 , 0.46987605, 0.23278789, 0.8560734 ,
#        0.14013254, 0.06941946, 0.40405323, 0.19947906, 0.36653539,
#        0.38767863, 0.20654453, 0.95708339, 0.69829557, 0.54875244,
#        0.82901948, 0.28274474, 0.85538732, 0.93553689, 0.08710929,
#        0.49837036, 0.78325369, 0.76118054, 0.29707785, 0.48000077,
#        0.80529711, 0.39000241, 0.79945461, 0.27534682, 0.75011687,
# ...
